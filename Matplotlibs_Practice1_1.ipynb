# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure(figsize=(7,7),facecolor='linen')

plt.subplot(211)
plt.subplot(212)
# Out:
# <AxesSubplot:>

# %%
fig=plt.figure()
ax=fig.add_subplot()

# %%
fig= plt.figure(figsize=(10,10),facecolor='linen')
fig.add_subplot(221)
fig.add_subplot(223)
fig.add_subplot(122)
# Out:
# <AxesSubplot:>

# %%
fig=plt.figure(figsize=(10,10), facecolor='linen')
ax=fig.add_subplot(211)
fig.add_subplot(212)
ax.plot([2,3,1])

# %%
fig= plt.figure(figsize=(10,10),facecolor='linen')
ax=fig.add_subplot(221)
ax1=fig.add_subplot(223)
ax2=fig.add_subplot(122,facecolor='y')

ax.plot([2,3,1])
ax1.plot([4,7,1])
ax2.plot([6,2,4],[4,2,7])

# %%
fig, axes = plt.subplots(2,2, figsize=(7,7),facecolor='linen')

axes[0,0].plot([2,3,1])
axes[0,1].plot([1,2,3])
axes[1,0].plot([2,1,3])
axes[1,1].plot([3,2,1])

# %%
test_np =np.array([[1,2],[3,4]])
print(test_np)
print(test_np[0])
print(test_np[1])
for idx,val in enumerate(test_np.flat):
    print(idx,val)
# Out:
# [[1 2]
#  [3 4]]
# [1 2]
# [3 4]
# 0 1
# 1 2
# 2 3
# 3 4

# %%
fig, axes=plt.subplots(3, 2, figsize=(7,7), facecolor='linen')
axes[0,0].plot([2,1,3])

for idx, ax in enumerate(axes.flat):
    print(idx,ax)
# Out:
# 0 AxesSubplot(0.125,0.653529;0.352273x0.226471)
# 1 AxesSubplot(0.547727,0.653529;0.352273x0.226471)
# 2 AxesSubplot(0.125,0.381765;0.352273x0.226471)
# 3 AxesSubplot(0.547727,0.381765;0.352273x0.226471)
# 4 AxesSubplot(0.125,0.11;0.352273x0.226471)
# 5 AxesSubplot(0.547727,0.11;0.352273x0.226471)

# %%
title_list=['Training image', '2 scale','4 scale', '6 scale','5 scale', '8 scale']

fig,axes =plt.subplots(2,3, figsize=(20,10))

for idx, ax in enumerate(axes.flat):
    ax.set_title(title_list[idx],fontsize=20)

# %%
fig =plt.figure(figsize=(20,20),facecolor='linen')
ax1=plt.subplot2grid((3,2),(0,0),fig=fig)
ax1.plot([1,3,2,5,4])
ax2=plt.subplot2grid((3,2),(1,1),fig=fig)
ax2.plot([2,3,4,5,6])
ax3=plt.subplot2grid((3,2),(2,0),fig=fig)
ax3.plot([1,3,8,5,6])

# %%
fig=plt.figure(figsize=(10,10),facecolor='linen')
ax1=fig.add_subplot(211)
ax2=fig.add_subplot(212)

# %%
fig, axes=plt.subplots(2,1, figsize=(10,10),facecolor='linen')

# %%
fig=plt.figure(figsize=(10,10),facecolor='linen')
ax1=plt.subplot2grid((2,1),(0,0),fig=fig)
ax2=plt.subplot2grid((2,1),(1,0),fig=fig)

# %%
fig=plt.figure(figsize=(10,10),facecolor='linen')
ax1=plt.subplot2grid((3,3),(0,0),colspan=2, fig=fig)
ax2=plt.subplot2grid((3,3),(0,2),rowspan=2, fig=fig)
ax3=plt.subplot2grid((3,3),(1,0),rowspan=2, fig=fig)
ax4=plt.subplot2grid((3,3),(2,1),colspan=2, fig=fig)
ax5=plt.subplot2grid((3,3),(1,1),fig=fig)

# %%
fig=plt.figure(figsize=(10,10),facecolor='linen')
ax1=fig.add_subplot(211)
ax2=fig.add_subplot(223)
ax3=fig.add_subplot(224)

# %%
fig=plt.figure(figsize=(10,10),facecolor='linen')
ax1=plt.subplot2grid((2,2),(0,0),colspan=2,fig=fig)
ax2=plt.subplot2grid((2,2),(1,0),fig=fig)
ax3=plt.subplot2grid((2,2),(1,1),fig=fig)

# %%
fig=plt.figure(figsize=(10,10))
ax1=fig.add_subplot(121)
ax2=fig.add_subplot(222,projection='3d')
ax3=fig.add_subplot(224,projection='3d')

# %%
fig=plt.figure(figsize=(10,10))
ax1=plt.subplot2grid((2,2),(0,0),rowspan=2,fig=fig)
ax2=plt.subplot2grid((2,2),(0,1),fig=fig,projection='3d')
ax3=plt.subplot2grid((2,2),(1,1),fig=fig,projection='3d')

# %%
fig=plt.figure(figsize=(10,10),facecolor='linen')
axes=np.empty(shape=(0,))
np.append(axes,plt.subplot2grid((5,4),(0,0),colspan=2,rowspan=2,fig=fig))
np.append(axes,plt.subplot2grid((5,4),(0,2),colspan=2,rowspan=2,fig=fig))

for i in range(2,5):
    for j in range(4):
        np.append(axes, plt.subplot2grid((5,4),(i,j),fig=fig))
axes
# Out:
# array([], dtype=float64)

# %%
fig=plt.figure(figsize=(10,10),facecolor='linen')
ax=fig.add_axes([0.1,0.1,0.8,0.8])

# %%
fig=plt.figure(figsize=(10,10),facecolor='linen')
ax1=fig.add_axes([0.1,0.1,0.5,0.5])
ax2=fig.add_axes([0.7,0.1,0.2,0.5])
ax3=fig.add_axes([0.1,0.7,0.8,0.2])

# %%
fig=plt.figure(figsize=(10,10),facecolor='linen')
ax=fig.add_subplot(111)
ax_zoom=fig.add_axes([0.4,0.4,0.45,0.45])
